# %% [markdown]
# # Demo for Patch data
# VR 2025-01-08

# %%
import retinanalysis as ra
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Parse h5 to json, then place h5 and json in database dirs, then populate database.

# %%
ra.populate_database()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ra.populate_database()
#
# File ~/Documents/GitHub/retinanalysis/src/retinanalysis/utils/database_utils.py:16, in populate_database(username, h5_dir, meta_dir, tags_dir)
#      11 def populate_database(username = USER, h5_dir = H5_DIR,
#      12                         meta_dir = META_DIR, tags_dir = TAGS_DIR):
#      14     db = dj.VirtualModule('schema.py', 'schema', create_schema=True)
# ---> 16     database_pop.append_data(h5_dir, meta_dir, tags_dir, username, db)
#
# File ~/Documents/GitHub/retinanalysis/src/retinanalysis/utils/database_pop.py:586, in append_data(data_dir, meta_dir, tags_dir, username, db_param)
#     583 user = username
#     584 fill_tables()
# --> 586 meta_list = gen_meta_list(data_dir, meta_dir, tags_dir)
#     587 records_added = 0
#     588 ls_new_exp = []
#
# File ~/Documents/GitHub/retinanalysis/src/retinanalysis/utils/database_pop.py:540, in gen_meta_list(data_dir, meta_dir, tags_dir)
#     538 while stack:
#     539     current_dir = stack.pop()
# --> 540     for item in os.listdir(current_dir):
#     541         full_path = os.path.join(current_dir, item)
#     542         if os.path.isdir(full_path):
#
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %%
ra.DJ_GUI.launch()           # starts Flask + Next.js, opens browser
# Out:
# Flask backend starting on http://127.0.0.1:5000
# Globals populated
#  * Serving Flask app 'dj_server.app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# Next.js frontend starting on http://localhost:3000
#
# DJ-GUI is running at http://localhost:3000
# Press Ctrl+C to stop.
# {'flask_thread': <Thread(Thread-5 (_run_flask), started daemon 123145686597632)>,
#  'next_process': <Popen: returncode: None args: ['npm', 'run', 'next-dev']>}
# 127.0.0.1 - - [31/Mar/2026 16:45:52] "GET /init/list-databases HTTP/1.1" 200 -
# Connected
# 127.0.0.1 - - [31/Mar/2026 16:45:54] "POST /init/connect-database HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Mar/2026 16:45:55] "GET /user/get-user HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Mar/2026 16:46:00] "GET /pop/is-empty HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Mar/2026 16:46:02] "GET /query/get-saved-queries HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Mar/2026 16:46:03] "GET /query/get-levels-and-fields HTTP/1.1" 200 -
# Querying
# Constructed query
# 100%|██████████| 413/413 [02:14<00:00,  3.08it/s]
# Query executed
# 127.0.0.1 - - [31/Mar/2026 16:48:34] "POST /query/execute-query HTTP/1.1" 200 -
# Querying
# Constructed query
#  10%|▉         | 41/413 [00:17<03:23,  1.83it/s]

# %%
ra.schema.Experiment() & 'is_mea=1'
# Out:
# *id    h5_uuid        exp_name      meta_file      data_file      tags_file      is_mea     date_added     label        properti attribut start_time     experimenter   institution    lab      project     rig      rig_type
# +----+ +------------+ +-----------+ +------------+ +------------+ +------------+ +--------+ +------------+ +----------+ +------+ +------+ +------------+ +------------+ +------------+ +------+ +---------+ +------+ +----------+
# 1      498dcf21-b568- 20230614C     /Volumes/data/ /Volumes/data/ /Volumes/data/ 1          2026-03-05 15: 20230614     json     json     2023-06-14 08: None           None           None     None        None     MEA
# 2      65489648-006d- 20230713C     /Volumes/data/ /Volumes/data/ /Volumes/data/ 1          2026-03-05 15: 20230713     json     json     2023-07-13 10: None           None           None     None        None     MEA
# 3      440fb989-fb5e- 20230719C     /Volumes/data/ /Volumes/data/ /Volumes/data/ 1          2026-03-05 15: 20230719     json     json     2023-07-19 07: None           None           None     None        None     MEA
# 4      9d64857f-7d2d- 20241010H     /Volumes/data/ /Volumes/data/ /Volumes/data/ 1          2026-03-05 15: 20241010     json     json     2024-10-10 09: None           None           None     None        None     MEA
# 5      3a7ca7c1-b424- 20241016C     /Volumes/data/ /Volumes/data/ /Volumes/data/ 1          2026-03-05 15: 20241016     json     json     2024-10-16 08: None           None           None     None        None     MEA
# 6      f9fa93ef-aff7- 20250128C     /Volumes/data/ /Volumes/data/ /Volumes/data/ 1          2026-03-05 15: 20250128     json     json     2025-01-28 08: None           None           None     None        None     MEA
# 7      345dd5e1-498a- 20220405C     /Volumes/data/ /Volumes/data/ /Volumes/data/ 1          2026-03-05 15: 20220405     json     json     2022-04-05 09: None           None           None     None        None     MEA
# 8      501a25d2-cc07- 20220406C     /Volumes/data/ /Volumes/data/ /Volumes/data/ 1          2026-03-05 15: 20220406     json     json     2022-04-06 11: None           None           None     None        None     MEA
# 9      09f80247-89e5- 20220412C     /Volumes/data/ /Volumes/data/ /Volumes/data/ 1          2026-03-05 15: 20220412     json     json     2022-04-12 09: None           None           None     None        None     MEA
# 10     94afe5fc-b406- 20220420C     /Volumes/data/ /Volumes/data/ /Volumes/data/ 1          2026-03-05 15: 20220420     json     json     2022-04-20 13: None           None           None     None        None     MEA
# 11     b0637fe4-0093- 20220426C     /Volumes/data/ /Volumes/data/ /Volumes/data/ 1          2026-03-05 15: 20220426     json     json     2022-04-26 10: None           None           None     None        None     MEA
# 12     22732560-b64d- 20220518C     /Volumes/data/ /Volumes/data/ /Volumes/data/ 1          2026-03-05 15: 20220518     json     json     2022-05-18 09: None           None           None     None        None     MEA
#    ...
#  (Total: 183)

# %%
df=ra.get_single_cell_dataset_summary()
# Out:
# Found 233 single-cell experiments.
#            exp_name  n_cells                              cell_types  \
# 0      2019-01-15_G        4                            RGC, unknown
# 1      2019-01-24_G        1                                 unknown
# 2      2019-02-20_G        1                                 unknown
# 3      2019-02-21_E        9                     onP, RGC, onM, offP
# 4      2019-02-22_G        1                                 unknown
# ..              ...      ...                                     ...
# 228  2026-02-24_E_2       11            Hor, onP, RGC, offP, BP, onM
# 229    2026-02-25_E       10  AC, onP, offM, unknown, RGC, offP, onM
# 230    2026-02-27_G        4                           SBC, onM, onP
# 231    2026-03-17_G        3                               onP, offP
# 232    2026-03-18_G        7                          offP, onP, onM
#
#                                          protocols_ran  species
# 0    DovesMovie, ChirpStimulus, MovingBar, SingleSp...  Primate
# 1    LedPulse, TwoLedContrastAdapt, LedPulseFamilyW...  Primate
# 2    DovesMovie, ChirpStimulus, SingleSpot, SplitFi...  Primate
# 3    SingleSpot, LedPulse, SplitFieldCentering, Exp...  Primate
# 4    SingleSpot, SplitFieldCentering, ExpandingSpot...  Primate
# ..                                                 ...      ...
# 228  DovesMovie, PresentImages, SingleSpot, Jittere...  Primate
# 229  SingleSpot, JitteredNoise, FlashMapper, Presen...  Primate
# 230                        LedPulse, VariableMeanNoise  Primate
# 231     LedPulse, LedPairPulse, ledSinusoidNoiseEpochs  Primate
# 232  LedPulse, LedPairPulse, asymmetricLedPairPulse...  Primate
#
# [233 rows x 5 columns]

# %%
ra.get_datasets_from_protocol_names_sc('variableMeanNoise')
# Out:
# Found 159 matching rows across 47 experiments.
#
#          exp_name      protocol_name species_type recording_technique  \
# 0    2019-04-18_E  VariableMeanNoise      Primate       cell-attached
# 1    2019-04-18_E  VariableMeanNoise      Primate       cell-attached
# 2    2020-04-15_B  VariableMeanNoise      Primate       cell-attached
# 3    2020-04-15_B  VariableMeanNoise      Primate       cell-attached
# 4    2020-04-15_B  VariableMeanNoise      Primate       cell-attached
# ..            ...                ...          ...                 ...
# 154  2026-02-05_G  VariableMeanNoise      Primate          whole-cell
# 155  2026-02-11_G  VariableMeanNoise      Primate                null
# 156  2026-02-27_G  VariableMeanNoise      Primate       cell-attached
# 157  2026-02-27_G  VariableMeanNoise      Primate                null
# 158  2026-02-27_G  VariableMeanNoise      Primate          whole-cell
#
#     cell_label pipette_solution               cell_type
# 0        Cell7             Ames           RGC\ON-midget
# 1        Cell8             Ames           RGC\ON-midget
# 2        Cell1             Ames          RGC\ON-parasol
# 3        Cell2             Ames         RGC\OFF-parasol
# 4        Cell3             Ames          RGC\ON-parasol
# ..         ...              ...                     ...
# 154      Cell2             null           RGC\ON-midget
# 155      Cell1             null                 unknown
# 156      Cell3             null          RGC\ON-parasol
# 157      Cell3             null          RGC\ON-parasol
# 158      Cell4             null  RGC\small bistratified
#
# [159 rows x 7 columns]
#          exp_name      protocol_name species_type recording_technique  \
# 0    2019-04-18_E  VariableMeanNoise      Primate       cell-attached
# 1    2019-04-18_E  VariableMeanNoise      Primate       cell-attached
# 2    2020-04-15_B  VariableMeanNoise      Primate       cell-attached
# 3    2020-04-15_B  VariableMeanNoise      Primate       cell-attached
# 4    2020-04-15_B  VariableMeanNoise      Primate       cell-attached
# ..            ...                ...          ...                 ...
# 154  2026-02-05_G  VariableMeanNoise      Primate          whole-cell
# 155  2026-02-11_G  VariableMeanNoise      Primate                null
# 156  2026-02-27_G  VariableMeanNoise      Primate       cell-attached
# 157  2026-02-27_G  VariableMeanNoise      Primate                null
# 158  2026-02-27_G  VariableMeanNoise      Primate          whole-cell
#
#     cell_label pipette_solution               cell_type
# 0        Cell7             Ames           RGC\ON-midget
# 1        Cell8             Ames           RGC\ON-midget
# 2        Cell1             Ames          RGC\ON-parasol
# 3        Cell2             Ames         RGC\OFF-parasol
# 4        Cell3             Ames          RGC\ON-parasol
# ..         ...              ...                     ...
# 154      Cell2             null           RGC\ON-midget
# 155      Cell1             null                 unknown
# 156      Cell3             null          RGC\ON-parasol
# 157      Cell3             null          RGC\ON-parasol
# 158      Cell4             null  RGC\small bistratified
#
# [159 rows x 7 columns]

# %%
exp_name = '2019-03-05_G'
ra.get_exp_summary(exp_name)
# Out:
#          exp_name   prep_label recording_technique  \
# 0    2019-03-05_G  Preparation       cell-attached
# 1    2019-03-05_G  Preparation       cell-attached
# 2    2019-03-05_G  Preparation       cell-attached
# 3    2019-03-05_G  Preparation       cell-attached
# 4    2019-03-05_G  Preparation       cell-attached
# ..            ...          ...                 ...
# 230  2019-03-05_G  Preparation          whole-cell
# 231  2019-03-05_G  Preparation          whole-cell
# 232  2019-03-05_G  Preparation          whole-cell
# 233  2019-03-05_G  Preparation          whole-cell
# 234  2019-03-05_G  Preparation          whole-cell
#
#                   pipette_solution  cell_id cell_label             cell_type  \
# 0                             Ames      404      Cell1       RGC\OFF-parasol
# 1                             Ames      404      Cell1       RGC\OFF-parasol
# 2                             Ames      404      Cell1       RGC\OFF-parasol
# 3                             Ames      404      Cell1       RGC\OFF-parasol
# 4                             Ames      404      Cell1       RGC\OFF-parasol
# ..                             ...      ...        ...                   ...
# 230  potassium zero calcium buffer      398     Cell16  photoreceptor\L cone
# 231  potassium zero calcium buffer      398     Cell16  photoreceptor\L cone
# 232  potassium zero calcium buffer      398     Cell16  photoreceptor\L cone
# 233  potassium zero calcium buffer      398     Cell16  photoreceptor\L cone
# 234  potassium zero calcium buffer      398     Cell16  photoreceptor\L cone
#
#      NDF                                      protocol_name  duration_minutes  \
# 0    NaN  edu.washington.riekelab.turner.protocols.Split...              0.12
# 1    NaN  edu.washington.riekelab.turner.protocols.Split...              0.08
# 2    NaN  edu.washington.riekelab.turner.protocols.Split...              0.08
# 3    NaN  edu.washington.riekelab.turner.protocols.Expan...              0.90
# 4    NaN  edu.washington.riekelab.turner.protocols.Expan...              0.75
# ..   ...                                                ...               ...
# 230  NaN       edu.washington.riekelab.protocols.SingleSpot              0.05
# 231  NaN  edu.washington.riekelab.baudin.protocols.ConeL...              1.82
# 232  NaN       edu.washington.riekelab.protocols.SingleSpot              0.07
# 233  NaN  edu.washington.riekelab.baudin.protocols.ConeL...              2.13
# 234  NaN       edu.washington.riekelab.protocols.SingleSpot              0.07
#
#      minutes_since_start          start_time            end_time  \
# 0                   0.12 2019-03-05 12:46:32 2019-03-05 12:46:39
# 1                   0.27 2019-03-05 12:46:43 2019-03-05 12:46:48
# 2                   0.40 2019-03-05 12:46:51 2019-03-05 12:46:56
# 3                   1.95 2019-03-05 12:47:35 2019-03-05 12:48:29
# 4                   3.10 2019-03-05 12:48:53 2019-03-05 12:49:38
# ..                   ...                 ...                 ...
# 230               573.12 2019-03-05 22:19:36 2019-03-05 22:19:39
# 231               575.05 2019-03-05 22:19:46 2019-03-05 22:21:35
# 232               575.25 2019-03-05 22:21:43 2019-03-05 22:21:47
# 233               577.58 2019-03-05 22:21:59 2019-03-05 22:24:07
# 234               577.78 2019-03-05 22:24:15 2019-03-05 22:24:19
#
#                       cell_properties group_label  experiment_id  prep_id  \
# 0         {'type': 'RGC\OFF-parasol'}     Control            218      258
# 1         {'type': 'RGC\OFF-parasol'}     Control            218      258
# 2         {'type': 'RGC\OFF-parasol'}     Control            218      258
# 3         {'type': 'RGC\OFF-parasol'}     Control            218      258
# 4         {'type': 'RGC\OFF-parasol'}     Control            218      258
# ..                                ...         ...            ...      ...
# 230  {'type': 'photoreceptor\L cone'}     Control            218      257
# 231  {'type': 'photoreceptor\L cone'}     Control            218      257
# 232  {'type': 'photoreceptor\L cone'}     Control            218      257
# 233  {'type': 'photoreceptor\L cone'}     Control            218      257
# 234  {'type': 'photoreceptor\L cone'}     Control            218      257
#
#      group_id  block_id  protocol_id
# 0        3121      5723           82
# 1        3121      5724           82
# 2        3121      5725           82
# 3        3121      5726           83
# 4        3121      5727           83
# ..        ...       ...          ...
# 230      3111      5612           18
# 231      3111      5613          109
# 232      3111      5614           18
# 233      3111      5615          110
# 234      3111      5616           18
#
# [235 rows x 20 columns]

# %% [markdown]
# For Cell1 ON-Parasol let's get the expanding spots data

# %%
df_exp = ra.get_exp_summary(exp_name)
cell_label = 'Cell2'
df_exp.query('cell_label == @cell_label')
# Out:
#         exp_name   prep_label recording_technique pipette_solution  cell_id  \
# 9   2019-03-05_G  Preparation       cell-attached             Ames       52
# 10  2019-03-05_G  Preparation       cell-attached             Ames       52
# 11  2019-03-05_G  Preparation       cell-attached             Ames       52
# 12  2019-03-05_G  Preparation       cell-attached             Ames       52
# 13  2019-03-05_G  Preparation       cell-attached             Ames       52
# 14  2019-03-05_G  Preparation       cell-attached             Ames       52
# 15  2019-03-05_G  Preparation          whole-cell           cesium       52
# 16  2019-03-05_G  Preparation          whole-cell           cesium       52
# 17  2019-03-05_G  Preparation          whole-cell           cesium       52
# 18  2019-03-05_G  Preparation          whole-cell           cesium       52
# 19  2019-03-05_G  Preparation          whole-cell           cesium       52
# 20  2019-03-05_G  Preparation          whole-cell           cesium       52
# 21  2019-03-05_G  Preparation          whole-cell           cesium       52
# 22  2019-03-05_G  Preparation          whole-cell           cesium       52
# 23  2019-03-05_G  Preparation          whole-cell           cesium       52
# 24  2019-03-05_G  Preparation          whole-cell           cesium       52
# 25  2019-03-05_G  Preparation          whole-cell           cesium       52
# 26  2019-03-05_G  Preparation          whole-cell           cesium       52
# 27  2019-03-05_G  Preparation          whole-cell           cesium       52
# 28  2019-03-05_G  Preparation          whole-cell           cesium       52
# 29  2019-03-05_G  Preparation          whole-cell           cesium       52
# 30  2019-03-05_G  Preparation          whole-cell           cesium       52
# 31  2019-03-05_G  Preparation          whole-cell           cesium       52
# 32  2019-03-05_G  Preparation          whole-cell           cesium       52
# 33  2019-03-05_G  Preparation          whole-cell           cesium       52
# 34  2019-03-05_G  Preparation          whole-cell           cesium       52
# 35  2019-03-05_G  Preparation          whole-cell           cesium       52
# 36  2019-03-05_G  Preparation          whole-cell           cesium       52
# 37  2019-03-05_G  Preparation          whole-cell           cesium       52
# 38  2019-03-05_G  Preparation          whole-cell           cesium       52
# 39  2019-03-05_G  Preparation          whole-cell           cesium       52
# 40  2019-03-05_G  Preparation          whole-cell           cesium       52
# 41  2019-03-05_G  Preparation          whole-cell           cesium       52
# 42  2019-03-05_G  Preparation          whole-cell           cesium       52
# 43  2019-03-05_G  Preparation          whole-cell           cesium       52
# 44  2019-03-05_G  Preparation          whole-cell           cesium       52
# 45  2019-03-05_G  Preparation          whole-cell           cesium       52
#
#    cell_label       cell_type  NDF  \
# 9       Cell2  RGC\ON-parasol  NaN
# 10      Cell2  RGC\ON-parasol  NaN
# 11      Cell2  RGC\ON-parasol  NaN
# 12      Cell2  RGC\ON-parasol  NaN
# 13      Cell2  RGC\ON-parasol  NaN
# 14      Cell2  RGC\ON-parasol  NaN
# 15      Cell2  RGC\ON-parasol  NaN
# 16      Cell2  RGC\ON-parasol  NaN
# 17      Cell2  RGC\ON-parasol  NaN
# 18      Cell2  RGC\ON-parasol  NaN
# 19      Cell2  RGC\ON-parasol  NaN
# 20      Cell2  RGC\ON-parasol  NaN
# 21      Cell2  RGC\ON-parasol  NaN
# 22      Cell2  RGC\ON-parasol  NaN
# 23      Cell2  RGC\ON-parasol  NaN
# 24      Cell2  RGC\ON-parasol  NaN
# 25      Cell2  RGC\ON-parasol  NaN
# 26      Cell2  RGC\ON-parasol  NaN
# 27      Cell2  RGC\ON-parasol  NaN
# 28      Cell2  RGC\ON-parasol  NaN
# 29      Cell2  RGC\ON-parasol  NaN
# 30      Cell2  RGC\ON-parasol  NaN
# 31      Cell2  RGC\ON-parasol  NaN
# 32      Cell2  RGC\ON-parasol  NaN
# 33      Cell2  RGC\ON-parasol  NaN
# 34      Cell2  RGC\ON-parasol  NaN
# 35      Cell2  RGC\ON-parasol  NaN
# 36      Cell2  RGC\ON-parasol  NaN
# 37      Cell2  RGC\ON-parasol  NaN
# 38      Cell2  RGC\ON-parasol  NaN
# 39      Cell2  RGC\ON-parasol  NaN
# 40      Cell2  RGC\ON-parasol  NaN
# 41      Cell2  RGC\ON-parasol  NaN
# 42      Cell2  RGC\ON-parasol  NaN
# 43      Cell2  RGC\ON-parasol  NaN
# 44      Cell2  RGC\ON-parasol  NaN
# 45      Cell2  RGC\ON-parasol  NaN
#
#                                         protocol_name  duration_minutes  \
# 9   edu.washington.riekelab.turner.protocols.Split...              0.08
# 10  edu.washington.riekelab.turner.protocols.Split...              0.08
# 11  edu.washington.riekelab.turner.protocols.Split...              0.08
# 12  edu.washington.riekelab.baudin.protocols.ConeL...              0.90
# 13  edu.washington.riekelab.baudin.protocols.ConeL...              4.15
# 14  edu.washington.riekelab.baudin.protocols.ConeL...              1.93
# 15       edu.washington.riekelab.protocols.SingleSpot              0.05
# 16       edu.washington.riekelab.protocols.SingleSpot              0.05
# 17       edu.washington.riekelab.protocols.SingleSpot              0.03
# 18       edu.washington.riekelab.protocols.SingleSpot              0.03
# 19  edu.washington.riekelab.baudin.protocols.ConeL...              2.13
# 20       edu.washington.riekelab.protocols.SingleSpot              0.05
# 21       edu.washington.riekelab.protocols.SingleSpot              0.05
# 22       edu.washington.riekelab.protocols.SingleSpot              0.05
# 23       edu.washington.riekelab.protocols.SingleSpot              0.03
# 24  edu.washington.riekelab.baudin.protocols.ConeL...              1.22
# 25  edu.washington.riekelab.baudin.protocols.ConeL...              1.00
# 26  edu.washington.riekelab.baudin.protocols.ConeL...              1.35
# 27  edu.washington.riekelab.baudin.protocols.ConeL...              1.52
# 28       edu.washington.riekelab.protocols.SingleSpot              0.05
# 29  edu.washington.riekelab.rieke.protocols.Contra...              1.33
# 30  edu.washington.riekelab.rieke.protocols.Contra...              0.83
# 31  edu.washington.riekelab.rieke.protocols.Contra...              0.82
# 32  edu.washington.riekelab.rieke.protocols.Contra...              0.82
# 33       edu.washington.riekelab.protocols.SingleSpot              0.05
# 34       edu.washington.riekelab.protocols.SingleSpot              0.05
# 35  edu.washington.riekelab.rieke.protocols.Contra...              1.18
# 36  edu.washington.riekelab.rieke.protocols.Contra...              0.82
# 37  edu.washington.riekelab.rieke.protocols.Contra...              0.83
# 38  edu.washington.riekelab.rieke.protocols.Contra...              0.83
# 39  edu.washington.riekelab.baudin.protocols.ConeL...              1.95
# 40       edu.washington.riekelab.protocols.SingleSpot              0.05
# 41       edu.washington.riekelab.protocols.SingleSpot              0.05
# 42  edu.washington.riekelab.baudin.protocols.ConeL...              1.45
# 43  edu.washington.riekelab.turner.protocols.Expan...              0.83
# 44       edu.washington.riekelab.protocols.SingleSpot              0.03
# 45  edu.washington.riekelab.turner.protocols.Expan...              1.23
#
#     minutes_since_start          start_time            end_time  \
# 9                 41.35 2019-03-05 13:27:48 2019-03-05 13:27:53
# 10                41.52 2019-03-05 13:27:58 2019-03-05 13:28:03
# 11                41.63 2019-03-05 13:28:05 2019-03-05 13:28:10
# 12                43.00 2019-03-05 13:28:38 2019-03-05 13:29:32
# 13                47.35 2019-03-05 13:29:44 2019-03-05 13:33:53
# 14                49.42 2019-03-05 13:34:01 2019-03-05 13:35:57
# 15                55.00 2019-03-05 13:41:29 2019-03-05 13:41:32
# 16                55.10 2019-03-05 13:41:35 2019-03-05 13:41:38
# 17                55.18 2019-03-05 13:41:41 2019-03-05 13:41:43
# 18                55.28 2019-03-05 13:41:47 2019-03-05 13:41:49
# 19                57.62 2019-03-05 13:42:01 2019-03-05 13:44:09
# 20                58.10 2019-03-05 13:44:35 2019-03-05 13:44:38
# 21                58.22 2019-03-05 13:44:42 2019-03-05 13:44:45
# 22                58.38 2019-03-05 13:44:52 2019-03-05 13:44:55
# 23                58.48 2019-03-05 13:44:59 2019-03-05 13:45:01
# 24                59.82 2019-03-05 13:45:08 2019-03-05 13:46:21
# 25                60.92 2019-03-05 13:46:27 2019-03-05 13:47:27
# 26                63.45 2019-03-05 13:48:38 2019-03-05 13:49:59
# 27                65.25 2019-03-05 13:50:16 2019-03-05 13:51:47
# 28                65.45 2019-03-05 13:51:56 2019-03-05 13:51:59
# 29                67.03 2019-03-05 13:52:14 2019-03-05 13:53:34
# 30                68.03 2019-03-05 13:53:44 2019-03-05 13:54:34
# 31                69.00 2019-03-05 13:54:43 2019-03-05 13:55:32
# 32                70.05 2019-03-05 13:55:46 2019-03-05 13:56:35
# 33                71.33 2019-03-05 13:57:49 2019-03-05 13:57:52
# 34                71.43 2019-03-05 13:57:55 2019-03-05 13:57:58
# 35                72.80 2019-03-05 13:58:09 2019-03-05 13:59:20
# 36                73.77 2019-03-05 13:59:29 2019-03-05 14:00:18
# 37                74.73 2019-03-05 14:00:26 2019-03-05 14:01:16
# 38                75.95 2019-03-05 14:01:39 2019-03-05 14:02:29
# 39                79.68 2019-03-05 14:04:16 2019-03-05 14:06:13
# 40                80.10 2019-03-05 14:06:35 2019-03-05 14:06:38
# 41                80.27 2019-03-05 14:06:45 2019-03-05 14:06:48
# 42                81.82 2019-03-05 14:06:54 2019-03-05 14:08:21
# 43                82.83 2019-03-05 14:08:32 2019-03-05 14:09:22
# 44                83.50 2019-03-05 14:10:00 2019-03-05 14:10:02
# 45                84.97 2019-03-05 14:10:16 2019-03-05 14:11:30
#
#                cell_properties group_label  experiment_id  prep_id  group_id  \
# 9   {'type': 'RGC\ON-parasol'}     Control             12       18        90
# 10  {'type': 'RGC\ON-parasol'}     Control             12       18        90
# 11  {'type': 'RGC\ON-parasol'}     Control             12       18        90
# 12  {'type': 'RGC\ON-parasol'}     Control             12       18        90
# 13  {'type': 'RGC\ON-parasol'}     Control             12       18        90
# 14  {'type': 'RGC\ON-parasol'}     Control             12       18        90
# 15  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 16  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 17  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 18  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 19  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 20  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 21  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 22  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 23  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 24  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 25  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 26  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 27  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 28  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 29  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 30  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 31  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 32  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 33  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 34  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 35  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 36  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 37  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 38  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 39  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 40  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 41  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 42  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 43  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 44  {'type': 'RGC\ON-parasol'}     Control             12       18        91
# 45  {'type': 'RGC\ON-parasol'}     Control             12       18        91
#
#     block_id  protocol_id
# 9        784            5
# 10       785            5
# 11       786            5
# 12       787           15
# 13       788           15
# 14       789           16
# 15       790            6
# 16       791            6
# 17       792            6
# 18       793            6
# 19       794           15
# 20       795            6
# 21       796            6
# 22       797            6
# 23       798            6
# 24       799           15
# 25       800           15
# 26       801           15
# 27       802           16
# 28       803            6
# 29       804           13
# 30       805           13
# 31       806           13
# 32       807           13
# 33       808            6
# 34       809            6
# 35       810           13
# 36       811           13
# 37       812           13
# 38       813           13
# 39       814           15
# 40       815            6
# 41       816            6
# 42       817           15
# 43       818            2
# 44       819            6
# 45       820            2

# %%
# Block ID from table above, or can query by protocol name etc.
block_id = 817
sb = ra.StimBlock(exp_name, block_id)

# Note we're using SCResponseBlock. b_spiking=True will run spike detection.
rb = ra.SCResponseBlock(exp_name, block_id, b_spiking=True)
# Out:
# Initializing StimBlock for 2019-03-05_G block 817
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Block ID from table above, or can query by protocol name etc.
#       2 block_id = 817
# ----> 3 sb = ra.StimBlock(exp_name, block_id)
#       5 # Note we're using SCResponseBlock. b_spiking=True will run spike detection.
#       6 rb = ra.SCResponseBlock(exp_name, block_id, b_spiking=True)
#
# File ~/Documents/GitHub/retinanalysis/src/retinanalysis/classes/stim.py:67, in StimBlock.__init__(self, exp_name, block_id, ls_params, b_LED, verbose, pkl_file)
#      64 epoch_block = schema.EpochBlock() & {'id': block_id}
#      65 self.d_epoch_block_params = epoch_block.fetch('parameters')[0]
# ---> 67 df_e = get_epoch_data_from_exp(exp_name, block_id, b_LED=self.b_LED, ls_params=ls_params)
#      68 self.df_epochs = df_e
#      69 self.parameter_names = list(df_e.at[0,'epoch_parameters'].keys())
#
# File ~/Documents/GitHub/retinanalysis/src/retinanalysis/utils/datajoint_utils.py:696, in get_epoch_data_from_exp(exp_name, block_id, b_LED, ls_params, stim_time_name)
#     691 else:
#     692     ls_order =  varying_params + \
#     693         ['exp_name', 'group_label', 'protocol_name', 'frame_times_ms',
#     694         'epoch_parameters'] + ls_time_cols + \
#     695         ['experiment_id', 'group_id', 'block_id', 'protocol_id', 'epoch_id']
# --> 696 df = df[ls_order]
#     698 if b_LED:
#     699     # Delete frame_times_ms column
#     700     df = df.drop(columns=['frame_times_ms'])
#
# File /opt/anaconda3/envs/retinanalysis/lib/python3.11/site-packages/pandas/core/frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/envs/retinanalysis/lib/python3.11/site-packages/pandas/core/indexes/base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File /opt/anaconda3/envs/retinanalysis/lib/python3.11/site-packages/pandas/core/indexes/base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['experiment_id'] not in index"

# %% [markdown]
# ## Plot example trace and summary spikes

# %%
sb.df_epochs.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sb.df_epochs.head()
#
# NameError: name 'sb' is not defined

# %%
spot_sizes = sb.df_epochs['currentSpotSize'].values

# %%
# Example trace from 3rd epoch
def plot_eg_trace(rb, sb, i_epoch):
    f, ax = plt.subplots(1, 1, figsize=(10, 5))
    raw = rb.amp_data[i_epoch]
    sts = rb.spike_times[i_epoch]
    time = np.arange(len(raw)) / rb.amp_sample_rate
    ax.plot(time, raw, label='Raw trace')
    ax.scatter(sts/rb.amp_sample_rate, raw[sts], color='r')
    pre_time = sb.df_epochs.at[i_epoch, 'preTime']
    # Hacky correction for first missing frame. Need to implement frame monitor based timing.
    pre_time -= 1/60 * 1000
    stim_time = sb.df_epochs.at[i_epoch, 'stimTime']
    offset_time = pre_time + stim_time
    ax.axvline(pre_time / 1000, c='k', label='Stim onset')
    ax.axvline(offset_time / 1000, c='grey', label='Stim offset')
    spot_size = sb.df_epochs.at[i_epoch, 'currentSpotSize']
    ax.set_title(f'Epoch index {i_epoch}\n{spot_size}um spot')
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Amplitude')
    ax.legend()

i_epoch = 2
plot_eg_trace(rb, sb, i_epoch)

# %%
def get_stim_nspikes(sb, rb, b_sub_baseline: bool=False):
    ls_nsps = []
    for e_idx in sb.df_epochs.index:
        pre_time = sb.df_epochs.at[e_idx, 'preTime']
        
        # Hacky correction for first missing frame. Need to implement frame monitor based timing.
        pre_time -= 1/60 * 1000
        stim_time = sb.df_epochs.at[e_idx, 'stimTime']
        offset_time = pre_time + stim_time
        # Convert from ms to samples
        onset_samples = int(np.round(pre_time * rb.amp_sample_rate / 1000))
        offset_samples = int(np.round(offset_time * rb.amp_sample_rate / 1000))
        sts = rb.spike_times[e_idx]
        n_sps = len(sts[(sts >= onset_samples) & (sts <= offset_samples)])
        if b_sub_baseline:
            n_baseline = len(sts[(sts < onset_samples)])
            n_sps -= n_baseline
        ls_nsps.append(n_sps)
    stim_spikes = np.array(ls_nsps)

    return stim_spikes

stim_spikes = get_stim_nspikes(sb, rb, b_sub_baseline=False)

# %%
plt.scatter(spot_sizes, stim_spikes, c='k')
plt.xlabel('Spot size (um)')
plt.ylabel('Number of spikes during spot flash period')
# Out:
# Text(0, 0.5, 'Number of spikes during spot flash period')
