# %% [markdown]
# # Single Cell data
# CC 2026-08-11

# %% [markdown]
# ## 1. Setup

# %%
import retinanalysis as ra
import matplotlib.pyplot as plt
import numpy as np

# Read-only single-cell database queries and notebook browsers.
from retinanalysis.SCutils import explore as sc
# Map new h5 files when needed.
report = ra.SCutils.update_single_cell_json()
# Out:
# Single-cell drive: /Volumes/ChrisNewSSD
# H5 folder: /Volumes/ChrisNewSSD/single_cell/chris_data/h5
# JSON folder: /Volumes/ChrisNewSSD/single_cell/chris_data/json
# New H5 files (2): 2026-09-02_G.h5, 2026-09-04_G.h5
# Parsing 2026-09-02_G.h5 -> 2026-09-02_G.json
# Parsing experiment sources.
# Parsing group 1 of 3...
# Parsing group: Control
# Parsing group 2 of 3...
# Parsing group: Control
# Parsing group 3 of 3...
# Parsing group: Control
# Parsing 2026-09-04_G.h5 -> 2026-09-04_G.json
# Parsing experiment sources.
# Parsing group 1 of 10...
# Parsing group: Control
# WARNING: No epochs found in block:
# Parsing group 2 of 10...
# Parsing group: Control
# Parsing group 3 of 10...
# Parsing group: Control
# Parsing group 4 of 10...
# Parsing group: Control
# Parsing group 5 of 10...
# Parsing group: Control
# Parsing group 6 of 10...
# Parsing group: Control
# Parsing group 7 of 10...
# Parsing group: Control
# Parsing group 8 of 10...
# Parsing group: Control
# Parsing group 9 of 10...
# Parsing group: Control
# Parsing group 10 of 10...
# Parsing group: Control
# JSON update complete: 2 created, 0 failed.

# %% [markdown]
# ## 2. Populate and refresh the database
#
# `populate_database()` ingests new experiments, refreshes experiments whose JSON changed, and returns the database freshness check in the same report. Canonical experiment names such as `YYYY-MM-DD_X.h5` are included; auxiliary and legacy files are ignored. By default only metadata and tags JSON files trigger a refresh. Pass `watch_data_file=True` to include H5 modification times.

# %%
# One call handles ingest, refresh, and the post-ingest stale-file check.
summary = ra.populate_database()
df_db = summary['experiments']
df_stale = summary['stale']

print(f"newly added : {len(summary['added'])}")
print(f"refreshed   : {len(summary['updated'])}")
print(f"errored     : {len(summary['skipped'])}")
print(f"database    : {len(df_db)} experiments; {len(df_stale)} still out of date")

if len(df_stale):
    display(df_stale[['exp_name', 'date_added', 'source_mtime', 'source_file']])

# ra.purge_experiments('2026-06-04_G')
# ra.purge_experiments(['2026-05-06_E', '2026-05-08_E'])

# Drop only rows that remain stale after populate.
# ra.purge_experiments(df_stale['exp_name'].tolist())

# Wipe the whole database (requires the literal confirmation token).
# ra.purge_database(confirm='YES_DELETE_ALL')

print(f'{len(df_db)} experiments currently in the database.')
# Out:
# /Users/chrischen/opt/anaconda3/envs/retinanalysis/lib/python3.11/site-packages/datajoint/settings.py:979: UserWarning: No datajoint.json found. Using defaults and environment variables. Run `dj.config.save_template()` to create a template configuration.
#   config = _create_config()
# Ingest source: /Volumes/ChrisNewSSD/single_cell/fred_data/h5
# Ingest source: /Volumes/ChrisNewSSD/single_cell/chris_data/h5
# Experiments:   0%|          | 0/529 [00:00<?, ?it/s]
# Already in database: 2026-04-24_E
# Already in database: 2026-03-19_E
# Already in database: 2026-04-03_E_2
# Already in database: 2026-04-03_E
# Already in database: 2026-04-04_E
# Already in database: 2026-03-03_E_1
# Already in database: 2026-03-03_E_2
# Already in database: 2026-03-03_E
# Already in database: 2026-03-04_E
# Already in database: 2026-03-05_E
# Already in database: 2026-03-09_E
# Already in database: 2026-03-10_E
# Already in database: 2026-03-17_E
# Already in database: 2026-03-18_E
# Already in database: 2026-02-26_E
# Already in database: 2019-01-15_G
# Already in database: 2019-01-24_G
# Already in database: 2023-05-17_B
# Already in database: 2023-06-07_F
# Already in database: 2023-06-13_F
# Already in database: 2023-06-21_F
# Already in database: 2023-07-25_F
# Already in database: 2023-08-08_F
# Already in database: 2022-11-14_B
# Already in database: 2022-01-04_B
# Already in database: 2022-01-18_B
# Already in database: 2022-01-31_B
# Already in database: 2022-02-17_B
# Already in database: 2022-02-23_B
# Already in database: 2022-04-06_B
# Already in database: 2022-04-20_B
# Already in database: 2022-04-26_B
# Already in database: 2022-05-10_B
# Already in database: 2022-05-17_B
# Already in database: 2022-05-18_B
# Already in database: 2022-05-31_B
# Already in database: 2022-06-07_B
# Already in database: 2019-02-20_G
# Already in database: 2022-08-09_B
# Already in database: 2022-08-16_B
# Already in database: 2022-08-18_B
# Already in database: 2022-08-23_B
# Already in database: 2022-10-06_B
# Already in database: 2019-02-21_E
# Already in database: 2019-02-22_G
# Already in database: 2019-02-26_E
# Already in database: 2019-02-26_G
# Already in database: 2019-03-05_G
# Already in database: 2019-03-08_E
# Already in database: 2019-03-12_E
# Already in database: 2019-03-13_G
# Already in database: 2019-03-26_E
# Already in database: 2019-03-26_G
# Already in database: 2019-03-27_G
# Already in database: 2019-04-08_G
# Already in database: 2019-04-09_G
# Already in database: 2019-04-16_E
# Already in database: 2019-04-16_G
# Already in database: 2019-04-18_E
# Already in database: 2026-05-06_G
# Already in database: 2026-03-18_G
# Already in database: 2019-05-02_E
# Already in database: 2019-05-02_G
# Already in database: 2019-05-08_G
# Already in database: 2019-05-10_E
# Already in database: 2019-05-10_G
# Already in database: 2019-05-22_E
# Already in database: 2019-05-22_G
# Already in database: 2019-05-28_E
# Already in database: 2019-05-30_E
# Already in database: 2019-05-30_G
# Already in database: 2019-06-06_G
# Already in database: 2019-06-10_G
# Already in database: 2019-06-20_G
# Already in database: 2019-06-26_G
# Already in database: 2019-07-17_G
# Already in database: 2019-07-24_G
# Already in database: 2019-07-31_G
# Already in database: 2019-08-12_G
# Already in database: 2019-08-14_G
# Already in database: 2019-08-16_G
# Already in database: 2019-08-21_G
# Already in database: 2019-08-23_G
# Already in database: 2019-10-29_G
# Already in database: 2019-10-30_G
# Already in database: 2019-11-26_G
# Already in database: 2019-12-03_E
# Already in database: 2019-12-12_E_nonRF
# Already in database: 2019-12-12_G
# Already in database: 2019-12-17_E
# Already in database: 2019-12-17_F
# Already in database: 2019-12-19_F_nonRF
# Already in database: 2021-07-06_B
# Already in database: 2021-07-07_B
# Already in database: 2021-07-13_B
# Already in database: 2021-07-19_B
# Already in database: 2021-07-27_B
# Already in database: 2021-08-18_B
# Already in database: 2021-08-19_B
# Already in database: 2021-09-07_B
# Already in database: 2021-09-10_B
# Already in database: 2021-09-13_B
# Already in database: 2021-09-16_B
# Already in database: 2021-09-21_B
# Already in database: 2021-09-23_B
# Already in database: 2021-09-28_B
# Already in database: 2021-10-07_B
# Already in database: 2021-10-14_B
# Already in database: 2021-10-28_B
# Already in database: 2021-11-02_B
# Already in database: 2021-11-22_B
# Already in database: 2021-12-16_B
# Already in database: 2022-08-03_G
# Already in database: 2023-02-02_G
# Already in database: 2023-05-02_G
# Already in database: 2024-01-30_F
# Already in database: 2024-04-24_G
# Already in database: 2024-05-14_G
# Already in database: 2024-05-23_G
# Already in database: 2024-08-20_G
# Already in database: 2024-08-27_F
# Already in database: 2024-09-26_G
# Already in database: 2024-10-16_G
# Already in database: 2024-12-19_F
# Already in database: 2025-01-14_F
# Already in database: 2025-01-21_G
# Already in database: 2025-01-28_G
# Already in database: 2025-02-04_B
# Already in database: 2025-02-12_G
# Already in database: 2025-02-19_G
# Already in database: 2025-03-06_G
# Already in database: 2025-03-13_B
# Already in database: 2025-03-20_B
# Already in database: 2025-04-08_B
# Already in database: 2025-04-09_B
# Already in database: 2025-04-17_G
# Already in database: 2025-12-16_G
# Already in database: 2026-01-02_G
# Already in database: 2026-01-13_G
# Already in database: 2026-01-14_G
# Already in database: 2026-01-28_G
# Already in database: 2026-02-03_G
# Already in database: 2026-02-05_G
# Already in database: 2026-02-11_G
# Already in database: 2026-02-27_G
# Already in database: 2026-05-07_G
# Already in database: 2026-05-08_G
# Already in database: 2026-05-27_G
# Already in database: 2026-06-02_G
# Already in database: 2026-06-04_G
# Already in database: 2026-07-15_G
# Already in database: 2026-08-04_G
# Already in database: 2026-08-12_G
# Already in database: 2026-08-10_G
# Already in database: 2026-08-18_G
# Already in database: 2026-08-12_G_2
# Already in database: 2026-08-18_G_2
# Already in database: 2022-09-09_B
# Adding /Volumes/ChrisNewSSD/single_cell/chris_data/json/2026-09-04_G.json
# Loading meta: /Volumes/ChrisNewSSD/single_cell/chris_data/json/2026-09-04_G.json
# Loading tags: /Volumes/ChrisNewSSD/single_cell/chris_data/json/2026-09-04_G.json
# Adding /Volumes/ChrisNewSSD/single_cell/chris_data/json/2026-09-02_G.json
# Loading meta: /Volumes/ChrisNewSSD/single_cell/chris_data/json/2026-09-02_G.json
# Loading tags: /Volumes/ChrisNewSSD/single_cell/chris_data/json/2026-09-02_G.json
# Already in database: 2026-03-17_G
# Already in database: 2026-04-10_G
#
# No experiments skipped due to errors.
# No new sorting chunks found in database, skipping cell type file population.
# newly added : 2
# refreshed   : 0
# errored     : 0
# database    : 752 experiments; 0 still out of date
# 752 experiments currently in the database.

# %% [markdown]
# ## 3. List single-cell experiments
#
# Experiments are shown in separate `chris_data` and `fred_data` tables. Each protocol gets its own row so a date is easier to scan; repeated experiment, project, and short cell-type values are visually grouped. Owner and species are kept only for the cascading browser and are omitted from the table.

# %%
# Section 3 has exactly these visible columns. Owner and species remain
# internal to the cascading browser and are not included here.
df_sc_exps = sc.list_experiments(show=False)

# Accept both the current singular column and an older, comma-joined
# `protocols` column from a module already cached in this kernel.
if 'protocols' in df_sc_exps.columns:
    df_sc_exps['protocol'] = df_sc_exps.pop('protocols').fillna('?').str.split(r',\s*', regex=True)
    df_sc_exps = df_sc_exps.explode('protocol', ignore_index=True)

section3_columns = ['exp_name', 'cell_types', 'protocol']
df_sc_exps = (df_sc_exps.loc[:, section3_columns]
              .drop_duplicates()
              .sort_values(['exp_name', 'protocol'], ignore_index=True))
sc.tree_table(df_sc_exps, levels=['exp_name', 'project', 'cell_types'], height=500)
# Out:
# <style>
# .ra-tbl { overflow: auto; }
# .ra-tbl table { border-collapse: collapse; font-size: 12.5px;
#                 font-variant-numeric: tabular-nums; }
# .ra-tbl th { position: sticky; top: 0; z-index: 1; text-align: left;
#              font-weight: 600; padding: 4px 12px 4px 0;
#              border-bottom: 1px solid rgba(128,128,128,0.6);
#              background: var(--jp-layout-color0, #fff); }
# .ra-tbl td { padding: 2px 12px 2px 0; vertical-align: top;
#              white-space: nowrap; }
# .ra-tbl tr.grp > td { border-top: 1px solid rgba(128,128,128,0.28); }
# .ra-tbl td.num { text-align: right; }
# .ra-tbl td.lead { font-weight: 600; }
# .ra-tbl summary { cursor: pointer; margin: 2px 0; }
# </style>
# <div class="ra-tbl" style="max-height:500px"><table><thead><tr><th>exp_name</th><th>cell_types</th><th>protocol</th></tr></thead><tbody><tr><td class="lead">2017-11-21_B</td><td>OFF-transient, ON-alpha</td><td>ExpandingSpots</td></tr><tr><td class="lead"></td><td></td><td>EyeMovementTrajectory</td></tr><tr class="grp"><td class="lead">2017-12-12_B</td><td>AII, rod bipolar</td><td>LedPulse</td></tr><tr><td class="lead"></td><td></td><td>LedPulseFamily</td></tr><tr class="grp"><td class="lead">2018-09-06_B</td><td>ON-alpha</td><td>ChirpStimulus</td></tr><tr><td class="lead"></td><td></td><td>ChirpStimulusLED</td></tr><tr><td class="lead"></td><td></td><td>LedPulse</td></tr><tr class="grp"><td class="lead">2018-10-05_B</td><td>?</td><td>SingleSpot</td></tr><tr class="grp"><td class="lead">2019-01-08_B</td><td>unknown</td><td>LedPulse</td></tr><tr><td class="lead"></td><td></td><td>PulseFamily</td></tr><tr class="grp"><td class="lead">2019-01-15_G</td><td>RGC, unknown</td><td>ChirpStimulus</td></tr><tr><td class="lead"></td><td></td><td>DovesMovie</td></tr><tr><td class="lead"></td><td></td><td>ExpandingSpots</td></tr><tr><td class="lead"></td><td></td><td>MovingBar</td></tr><tr><td class="lead"></td><td></td><td>ObjectMotionGrating</td></tr><tr><td class="lead"></td><td></td><td>OrientedBars</td></tr><tr><td class="lead"></td><td></td><td>SingleSpot</td></tr><tr><td class="lead"></td><td></td><td>SplitFieldCentering</td></tr><tr class="grp"><td class="lead">2019-01-24_G</td><td>?</td><td>LedPulse</td></tr><tr><td class="lead"></td><td></td><td>LedPulseFamilyWithNegative</td></tr><tr><td class="lead"></td><td></td><td>TwoLedContrastAdapt</td></tr><tr class="grp"><td class="lead">2019-01-29_B</td><td>unknown</td><td>LedPulse</td></tr><tr><td class="lead"></td><td></td><td>PulseFamily</td></tr><tr class="grp"><td class="lead">2019-02-12_B</td><td>?, unknown</td><td>LedPulse</td></tr><tr><td class="lead"></td><td></td><td>PulseFamily</td></tr><tr class="grp"><td class="lead">2019-02-20_G</td><td>?</td><td>ChirpStimulus</td></tr><tr><td class="lead"></td><td></td><td>ContrastReversingGratingPlusMean</td></tr><tr><td class="lead"></td><td></td><td>DovesMovie</td></tr><tr><td class="lead"></td><td></td><td>ExpandingSpots</td></tr><tr><td class="lead"></td><td></td><td>GaussianNoise</td></tr><tr><td class="lead"></td><td></td><td>SingleSpot</td></tr><tr><td class="lead"></td><td></td><td>SplitFieldCentering</td></tr><tr class="grp"><td class="lead">2019-02-21_E</td><td>OFF-parasol, ON-midget, ON-parasol, RGC</td><td>ContrastReversingGratingPlusMean</td></tr><tr><td class="lead"></td><td></td><td>ExpandingSpots</td></tr><tr><td class="lead"></td><td></td><td>LedPulse</td></tr><tr><td class="lead"></td><td></td><td>SingleSpot</td></tr><tr><td class="lead"></td><td></td><td>SplitFieldCentering</td></tr><tr><td class="lead"></td><td></td><td>TwoLedContrastAdapt</td></tr><tr><td class="lead"></td><td></td><td>TwoLedNoise</td></tr><tr class="grp"><td class="lead">2019-02-22_B</td><td>ON-parasol, RGC</td><td>ContrastReversingGrating</td></tr><tr><td class="lead"></td><td></td><td>DovesMovie</td></tr><tr><td class="lead"></td><td></td><td>ExpandingSpots</td></tr><tr><td class="lead"></td><td></td><td>MovingBar</td></tr><tr><td class="lead"></td><td></td><td>OrientedBars</td></tr><tr><td class="lead"></td><td></td><td>SingleSpot</td></tr><tr><td class="lead"></td><td></td><td>SplitFieldCentering</td></tr><tr class="grp"><td class="lead">2019-02-22_G</td><td>?</td><td>ContrastReversingGratingPlusMean</td></tr><tr><td class="lead"></td><td></td><td>ExpandingSpots</td></tr><tr><td class="lead"></td><td></td><td>SingleSpot</td></tr><tr><td class="lead"></td><td></td><td>SplitFieldCentering</td></tr><tr class="grp"><td class="lead">2019-02-26_E</td><td>L cone, OFF-midget, OFF-parasol, ON-parasol</td><td>ConeLinearizationFullField</td></tr><tr><td class="lead"></td><td></td><td>ConeLinearizationSplitField</td></tr><tr><td class="lead"></td><td></td><td ...
# '\n<style>\n.ra-tbl { overflow: auto; }\n.ra-tbl table { border-collapse: collapse; font-size: 12.5px;\n                font-variant-numeric: tabular-nums; }\n.ra-tbl th { position: sticky; top: 0; z-index: 1; text-align: left;\n             font-weight: 600; padding: 4px 12px 4px 0;\n             border-bottom: 1px solid rgba(128,128,128,0.6);\n             background: var(--jp-layout-color0, #fff); }\n.ra-tbl td { padding: 2px 12px 2px 0; vertical-align: top;\n             white-space: nowrap; }\n.ra-tbl tr.grp > td { border-top: 1px solid rgba(128,128,128,0.28); }\n.ra-tbl td.num { text-align: right; }\n.ra-tbl td.lead { font-weight: 600; }\n.ra-tbl summary { cursor: pointer; margin: 2px 0; }\n</style>\n<div class="ra-tbl" style="max-height:500px"><table><thead><tr><th>exp_name</th><th>cell_types</th><th>protocol</th></tr></thead><tbody><tr><td class="lead">2017-11-21_B</td><td>OFF-transient, ON-alpha</td><td>ExpandingSpots</td></tr><tr><td class="lead"></td><td></td><td>EyeMovementTrajectory</td></tr><tr class="grp"><td class="lead">2017-12-12_B</td><td>AII, rod bipolar</td><td>LedPulse</td></tr><tr><td class="lead"></td><td></td><td>LedPulseFamily</td></tr><tr class="grp"><td class="lead">2018-09-06_B</td><td>ON-alpha</td><td>ChirpStimulus</td></tr><tr><td class="lead"></td><td></td><td>ChirpStimulusLED</td></tr><tr><td class="lead"></td><td></td><td>LedPulse</td></tr><tr class="grp"><td class="lead">2018-10-05_B</td><td>?</td><td>SingleSpot</td></tr><tr class="grp"><td class="lead">2019-01-08_B</td><td>unknown</td><td>LedPulse</td></tr><tr><td class="lead"></td><td></td><td>PulseFamily</td></tr><tr class="grp"><td class="lead">2019-01-15_G</td><td>RGC, unknown</td><td>ChirpStimulus</td></tr><tr><td class="lead"></td><td></td><td>DovesMovie</td></tr><tr><td class="lead"></td><td></td><td>ExpandingSpots</td></tr><tr><td class="lead"></td><td></td><td>MovingBar</td></tr><tr><td class="lead"></td><td></td><td>ObjectMotionGrating</td></tr><tr><td class="lead"></td><td></td><td>OrientedBars</td></tr><tr><td class="lead"></td><td></td><td>SingleSpot</td></tr><tr><td class="lead"></td><td></td><td>SplitFieldCentering</td></tr><tr class="grp"><td class="lead">2019-01-24_G</td><td>?</td><td>LedPulse</td></tr><tr><td class="lead"></td><td></td><td>LedPulseFamilyWithNegative</td></tr><tr><td class="lead"></td><td></td><td>TwoLedContrastAdapt</td></tr><tr class="grp"><td class="lead">2019-01-29_B</td><td>unknown</td><td>LedPulse</td></tr><tr><td class="lead"></td><td></td><td>PulseFamily</td></tr><tr class="grp"><td class="lead">2019-02-12_B</td><td>?, unknown</td><td>LedPulse</td></tr><tr><td class="lead"></td><td></td><td>PulseFamily</td></tr><tr class="grp"><td class="lead">2019-02-20_G</td><td>?</td><td>ChirpStimulus</td></tr><tr><td class="lead"></td><td></td><td>ContrastReversingGratingPlusMean</td></tr><tr><td class="lead"></td><td></td><td>DovesMovie</td></tr><tr><td class="lead"></td><td></td><td>ExpandingSpots</td></tr><tr><td class="lead"></td><td></td><td>GaussianNoise</td></tr><tr><td class="lead"></td><td></td><td>SingleSpot</td></tr><tr><td class="lead"></td><td></td><td>SplitFieldCentering</td></tr><tr class="grp"><td class="lead">2019-02-21_E</td><td>OFF-parasol, ON-midget, ON-parasol, RGC</td><td>ContrastReversingGratingPlusMean</td></tr><tr><td class="lead"></td><td></td><td>ExpandingSpots</td></tr><tr><td class="lead"></td><td></td><td>LedPulse</td></tr><tr><td class="lead"></td><td></td><td>SingleSpot</td></tr><tr><td class="lead"></td><td></td><td>SplitFieldCentering</td></tr><tr><td class="lead"></td><td></td><td>TwoLedContrastAdapt</td></tr><tr><td class="lead"></td><td></td><td>TwoLedNoise</td></tr><tr class="grp"><td class="lead">2019-02-22_B</td><td>ON-parasol, RGC</td><td>ContrastReversingGrating</td></tr><tr><td class="lead"></td><td></td><td>DovesMovie</td></tr><tr><td class="lead"></td><td></td><td>ExpandingSpots</td></tr><tr><td class="lead"></td><td></td><td>MovingBar</td></tr><tr><td class="lead"></t ...

# %% [markdown]
# ### 4.1 Protocol coverage by species
#
# One row per short protocol. Counts are unique experiment dates, not epoch blocks: `primate_dates` and `mouse_dates` show species-specific coverage, and `total_dates` includes every species.

# %%
# Scrollable protocol inventory, sorted by the number of dates.
df_protocol_inventory = sc.protocol_inventory(height=500)
# Out:
# 134 protocols across 530 experiment dates.
# <style>
# .ra-tbl { overflow: auto; }
# .ra-tbl table { border-collapse: collapse; font-size: 12.5px;
#                 font-variant-numeric: tabular-nums; }
# .ra-tbl th { position: sticky; top: 0; z-index: 1; text-align: left;
#              font-weight: 600; padding: 4px 12px 4px 0;
#              border-bottom: 1px solid rgba(128,128,128,0.6);
#              background: var(--jp-layout-color0, #fff); }
# .ra-tbl td { padding: 2px 12px 2px 0; vertical-align: top;
#              white-space: nowrap; }
# .ra-tbl tr.grp > td { border-top: 1px solid rgba(128,128,128,0.28); }
# .ra-tbl td.num { text-align: right; }
# .ra-tbl td.lead { font-weight: 600; }
# .ra-tbl summary { cursor: pointer; margin: 2px 0; }
# </style>
# <div class="ra-tbl" style="max-height:500px"><table><thead><tr><th>protocol</th><th>primate_dates</th><th>mouse_dates</th><th>total_dates</th></tr></thead><tbody><tr><td>SingleSpot</td><td class="num">245</td><td class="num">79</td><td class="num">331</td></tr><tr><td>ExpandingSpots</td><td class="num">260</td><td class="num">57</td><td class="num">327</td></tr><tr><td>SplitFieldCentering</td><td class="num">236</td><td class="num">37</td><td class="num">281</td></tr><tr><td>VariableMeanNoise</td><td class="num">122</td><td class="num">16</td><td class="num">141</td></tr><tr><td>LedPulse</td><td class="num">85</td><td class="num">38</td><td class="num">125</td></tr><tr><td>ContrastReversingGrating</td><td class="num">45</td><td class="num">51</td><td class="num">97</td></tr><tr><td>DovesMovie</td><td class="num">57</td><td class="num">1</td><td class="num">59</td></tr><tr><td>LinearEquivalentDisc</td><td class="num">21</td><td class="num">37</td><td class="num">58</td></tr><tr><td>JitteredNoise</td><td class="num">46</td><td class="num">0</td><td class="num">51</td></tr><tr><td>LedNoiseFamily</td><td class="num">40</td><td class="num">7</td><td class="num">48</td></tr><tr><td>EyeMovementTrajectory</td><td class="num">42</td><td class="num">1</td><td class="num">44</td></tr><tr><td>PulseFamily</td><td class="num">21</td><td class="num">16</td><td class="num">42</td></tr><tr><td>FullFieldNoise</td><td class="num">32</td><td class="num">7</td><td class="num">40</td></tr><tr><td>LinearEquivalentAnnulus</td><td class="num">38</td><td class="num">0</td><td class="num">39</td></tr><tr><td>AdaptationNegation</td><td class="num">26</td><td class="num">10</td><td class="num">36</td></tr><tr><td>MovingBar</td><td class="num">28</td><td class="num">5</td><td class="num">35</td></tr><tr><td>LedPulseFamily</td><td class="num">20</td><td class="num">10</td><td class="num">31</td></tr><tr><td>ConeLinearizationGratingPlusMean</td><td class="num">29</td><td class="num">0</td><td class="num">29</td></tr><tr><td>ContrastResponseSpots</td><td class="num">11</td><td class="num">17</td><td class="num">28</td></tr><tr><td>ExpandingGratings</td><td class="num">28</td><td class="num">0</td><td class="num">28</td></tr><tr><td>FlashedGratePlusNoise</td><td class="num">25</td><td class="num">0</td><td class="num">28</td></tr><tr><td>spotWithAnnularGrating</td><td class="num">24</td><td class="num">0</td><td class="num">28</td></tr><tr><td>ContrastReversingGratingPlusMean</td><td class="num">25</td><td class="num">0</td><td class="num">26</td></tr><tr><td>FlashedGrating</td><td class="num">2</td><td class="num">23</td><td class="num">25</td></tr><tr><td>OrientedBars</td><td class="num">21</td><td class="num">0</td><td class="num">23</td></tr><tr><td>NaturalImageFlash</td><td class="num">17</td><td class="num">2</td><td class="num">21</td></tr><tr><td>monitorVariableMeanNoiseEpochs</td><td class="num">21</td><td class="num">0</td><td class="num">21</td></tr><tr><td>ChirpStimulus</td><td class="num">15</td><td class="num">4</td><td class="num">20</td></tr><tr><td>ExpandingGratingMasks</td><td class="num">20</td><td class="num">0</td><td class="num">20</td></tr><tr><td>ObjectMotionDots</td><td class="num">19</td><td class="num">0</td><td class="num">20</td></tr><tr><td>LinearEquivalentDiscConeLin</td><td class="num">19</td><td class="num">0</td><td class="num">19</td></tr><tr><td>ContrastReversingGratingPlusMean_chris</td><td class="num">18</td><td class="num">0</td><td class="num">18</td></tr><tr><td>FlashedGratingChris</td><td class="num">4</td><td class="num">14</td><td class="num">18</td></tr><tr><td>PresentImages</td><td class="num">16</td><td class="num">0</td><td class="num">17</td></tr><tr><td>PresentMoviesFixedSize</td><td class="num">16</td><td class="num">0</td><td class="num">17</td></tr><tr><td>NaturalImageFlashPlusNoise</td><td class="num">16</td><td class="num">0</td><td class="num">16</td></tr><tr><td>Pulse</td><td class="num">13</td><td class ...

# %% [markdown]
# ## 4. Find experiments by protocol
#
# Search protocol names case-insensitively. The returned DataFrame remains one row per epoch block. The expanded block table shows fixed NDF settings plus the actual numeric filter-wheel reading for every block; an embedded `FWx` label is not used in place of the wheel reading.

# %%
df_blocks = sc.find_blocks('VariableMeanNoise')
# Out:
# 2208 blocks | 166 experiments | 4 protocol(s) matching 'VariableMeanNoise'
# <style>
# .ra-tbl { overflow: auto; }
# .ra-tbl table { border-collapse: collapse; font-size: 12.5px;
#                 font-variant-numeric: tabular-nums; }
# .ra-tbl th { position: sticky; top: 0; z-index: 1; text-align: left;
#              font-weight: 600; padding: 4px 12px 4px 0;
#              border-bottom: 1px solid rgba(128,128,128,0.6);
#              background: var(--jp-layout-color0, #fff); }
# .ra-tbl td { padding: 2px 12px 2px 0; vertical-align: top;
#              white-space: nowrap; }
# .ra-tbl tr.grp > td { border-top: 1px solid rgba(128,128,128,0.28); }
# .ra-tbl td.num { text-align: right; }
# .ra-tbl td.lead { font-weight: 600; }
# .ra-tbl summary { cursor: pointer; margin: 2px 0; }
# </style>
# <div class="ra-tbl" style="max-height:400px"><table><thead><tr><th>exp_name</th><th>blocks</th><th>protocols</th><th>block_ids</th></tr></thead><tbody><tr><td>2019-03-12_E</td><td class="num">19</td><td>VariableMeanNoise</td><td>5911-5913, 5936-5938, 5969-5971, 5997-5999, 6009, 6015-6017, 6029-6031</td></tr><tr><td>2019-04-16_E</td><td class="num">21</td><td>VariableMeanNoise</td><td>6536-6538, 6569-6572, 6584-6588, 6603-6606, 6615, 6619-6622</td></tr><tr><td>2019-04-18_E</td><td class="num">14</td><td>VariableMeanNoise</td><td>6708-6717, 6729-6732</td></t
10137, 10142, 10145-10146, 10149, 10151-10154, 10156-10157, 10159-10163, 10167-10168, 10171, 10173, 10175-10176, 10179, 10181-10182, 10184, 10186-10188</td></tr><tr><td>2020-08-13_G</td><td class="num">8</td><td>VariableMeanNoise</td><td>10191, 10193-10196, 10199-10201</td></tr><tr><td>2020-08-18_G</td><td class="num">3</td><td>VariableMeanNoise</td><td>10204, 10206, 10208</td></tr><tr><td>2020-08-24_G</td><td class="num">18</td><td>VariableMeanNoise</td><td>10212, 10214, 10216, 10218-10219, 10222, 10224-10228, 10231, 10233-10234, 10236-10237, 10240, 10243</td></tr><tr><td>2020-08-25_G</td><td class="num">8</td><td>VariableMeanNoise</td><td>10256, 10260, 10262-10263, 10267, 10270, 10273, 10275</td></tr><tr><t ...
# <style>
# .ra-tbl { overflow: auto; }
# .ra-tbl table { border-collapse: collapse; font-size: 12.5px;
#                 font-variant-numeric: tabular-nums; }
# .ra-tbl th { position: sticky; top: 0; z-index: 1; text-align: left;
#              font-weight: 600; padding: 4px 12px 4px 0;
#              border-bottom: 1px solid rgba(128,128,128,0.6);
#              background: var(--jp-layout-color0, #fff); }
# .ra-tbl td { padding: 2px 12px 2px 0; vertical-align: top;
#              white-space: nowrap; }
# .ra-tbl tr.grp > td { border-top: 1px solid rgba(128,128,128,0.28); }
# .ra-tbl td.num { text-align: right; }
# .ra-tbl td.lead { font-weight: 600; }
# .ra-tbl summary { cursor: pointer; margin: 2px 0; }
# </style>
# <div class="ra-tbl"><details><summary>all 2208 blocks</summary><div class="ra-tbl" style="max-height:400px"><table><thead><tr><th>exp_name</th><th>protocol</th><th>block_id</th><th>NDF + FW</th></tr></thead><tbody><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">5911</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">5912</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">5913</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">5936</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">5937</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">5938</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">5969</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">5970</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">5971</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">5997</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">5998</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">5999</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">6009</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">6015</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">6016</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">6017</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">6029</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">6030</td><td>E2</td></tr><tr><td>2019-03-12_E</td><td>VariableMeanNoise</td><td class="num">6031</td><td>E2</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6536</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6537</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6538</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6569</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6570</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6571</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6572</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6584</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6585</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6586</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6587</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6588</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6603</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6604</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6605</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6606</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6615</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6619</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6620</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6621</td><td>E1</td></tr><tr><td>2019-04-16_E</td><td>VariableMeanNoise</td><td class="num">6622</td><td>E1</td></tr><tr><td>2019-04-18_E</td><td>VariableMeanNoise</td><td class="num">6708</td><td>E1</td></tr><tr><td>2019-0 ...

# %% [markdown]
# ## 5. Browse and summarize experiments
#
# Use the cascading menus to select data owner, species, and experiment. Each experiment date appears once in the menu, regardless of how many protocols ran that day. The overview is organized as cell → epoch group (group label) → protocol, with block and epoch counts. Then select an epoch block and click **Load original traces** to read and display every unprocessed Amp1 epoch trace from the H5 file.

# %%
# Pass one row per date to the browser; Section 3 intentionally has one
# row per protocol and must not duplicate dates in this menu.
browser_dates = df_sc_exps[['exp_name']].drop_duplicates(ignore_index=True)
experiment_browser = sc.summarize_experiments(browser_dates)
# Out:
# VBox(children=(HBox(children=(Dropdown(description='Data:', layout=Layout(width='260px'), options=(('chris_dat…
